# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMOGRAMAN**
#
# **“INTRODUCTION TO PYTHON, VISUAL STUDIO CODE, AND CONNECTION TO GITHUB”**
#
# **Disusun Oleh :**
#
# **Matt Anita**
#
# **2611528001**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="../images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h1 align = "center">FOREWORD </h1>
#
# Praise and gratitude the author expresses to God Almighty, who has given His grace and blessing, so that the author can complete the practical report on the introduction to basic Python, VS Code, and connection to GitHub, which was carried out as the first session for the Practical Algorithm and Programming course. This practical session focuses on the discussion.
#
# Through this practical work, the expected outcome is that the author can understand and directly implement the basic Python concepts in a real project.
#
# The author realizes that this practical report still has many shortcomings. Therefore, constructive criticism and suggestions are highly appreciated for improvement and development in the future.
#
# Padang, 2026

# %% [markdown]
# ---
# <h1 align = "center">  CHAPTER I </h1>
# <h1 align = "center">  INTRODUCTION </h1>
#
#
# ## 1.1 background
# VS Code has a very close relationship with programming languages, and Python is one of the most popular programming languages lately. As a programmer, we need to have skills in using Python, but before starting to create a program, we first need to understand the basics of VS Code, Python, and connection to GitHub.
#
# This practical session aims to introduce the basics of Python, how to use VS Code, and how to connect projects to GitHub so that students get used to the modern software development ecosystem.
#
# ## 1.2 purpose
# 1. Students are expected to be able to recognize and use the VS Code application.
# 2. Students are expected to be able to learn about the Python language, from the basics to running a simple program.
# 3. Students are expected to be able to understand GitHub and Git applications and how to connect them with VS Code.
#
# ## 1.3 benefit
# 1. Improve understanding, basic introduction to the Python language and creating basic programs
# 2. Have an understanding of VS Code and use GitHub as a tool in programming

# %% [markdown]
# ---
# <h1 align = "center">   CHAPTER II</h1>
# <h1 align = "center">  DISCUSSION </h1>
#
#
# ## 2.1 Theoretical Basis
#
# ### 1. Python
#  Python is a computer programming language commonly used to build websites, software/apps, automate tasks, and perform data analysis. This programming language is considered a general-purpose language. This means it can be used to create various different programs, not just for specific problems. Because of its versatility and ease of use, it has become the most widely used programming language, especially for beginners.<br>
#
# ### 2. Visual Studio Code (VS Code)
#  Visual Code Studio is a free code editor that can run on desktop devices based on Linux, Windows, and Mac OS, developed by Microsoft. The Visual Studio Code application is a powerful software editor but still lightweight when used.
#
#  Visual Editor Code has several interesting features, here are the features of VS Code.<br>
#
#   a. Basic Editing<br>
#   b. IntelliSense<br>
#  c. Debugging<br>
#  d. Extension Marketplace<br>
#   e. Github Integration<br>
#
#
# ### 3. GitHub and Git
#
# GitHub is a cloud-based service that provides a place to host Git repositories. With GitHub, developers can store their projects online, share code, collaborate with others, and manage their software versions more efficiently.<br>
#
# Git is a distributed version control system that lets developers keep track of changes made to source code during software development.<br>

# %% [markdown]
# ## 2.2 Program Code
#
# ### 2.2.1 Program "A_2611532015"
# Run the code cell below so Jupyter automatically saves the code along with its output as one unit (no need for separate screenshots of the run results).

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro
"""
print("Hello World")
print()
print("program ini menghasilkan")
print("empat baris output")
print("/ \\ // \\\ ///")
print("program ini" +" dibuat oleh a/n"
+ "Matt Anita 2611528001" )

# %% [markdown]
# **Explanation :**
# 1. Lines 1-6 are comment lines, these are just notes/explanations for the programmer, not commands. (#) is for a one-line comment, while ("""...""") is for multi-line comments.
# 2. Lines 7-10 are (print) commands to display text exactly as it is.
# 3. Line 11 is the  sign that's how Python writes a single backslash (). The  part is a bit weird and actually makes Python give a warning, but the program still works.
# 4. Line 12 still uses (print), but the + sign here is used to join 3 pieces of text into one long sentence. It's important to note that there's no space between "a/n" and "Aria", so later it will stick together as one.

# %% [markdown]
# ---
# <h1 align = "center">CHAPTER III</h1>
#
# <h1 align = "center">CONCLUSION</h1>
#
# The practicum 'Introduction to Python, VS Code, and Connection to GitHub' provides a basic understanding of the VS Code application, introduces the Python language and its basics, and familiarizes with Git, GitHub, and its connection to VS Code.

# %% [markdown]
# ---
# <h1 align = "center">BIBLIOGRAPHY</h1>
#
# 1. Binus University (2025). The Difference Between Git and GitHub. https://binus.ac.id (access 7 September 2026)<br>
# 2. Coding Studio (2023). Visual Studio Code: Definition, Features, and Advantages. https://codingstudio.id (access 7 September 2026.)<br>
# 3.  Dicoding (2023). Python: Understanding, Examples of Use, and Benefits of Learning It. https://www.dicoding.com (access 7 September 2026)
